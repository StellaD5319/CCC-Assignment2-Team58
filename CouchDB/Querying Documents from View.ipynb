# %%
# from cloudant.client import Cloudant, CouchDB
import couchdb
import json

# connect couchdb
# client = couchdb.Server(url='http://admin:admin@172.26.132.57:5984')
# client = couchdb.Server(url='http://ccc58:ccc58@172.26.133.152:5984')
client = couchdb.Server(url='http://ccc58:ccc58@172.26.129.170:5984')

# %%
for dbname in client:
    print(dbname)
# Out:
# _replicator
# _users
# adelaide
# adelaide_tl
# adelaide_tl7
# adelaide_user_info
# brisbane
# brisbane_tl
# brisbane_tl7
# brisbane_user_info
# canberr
# canberra
# canberra_tl7
# melbourne
# melbourne_tl
# melbourne_tl7
# melbourne_tl77
# melbourne_tl7_14
# melbourne_user_info
# mydb
# perth
# perth_tl
# perth_tl7
# perth_user_info
# sydney
# sydney_tl
# sydney_tl7
# sydney_user_info
# tweets_mixed
# whole
# whole_au
# whole_au_30

# %%
dbname = "canberra"
if dbname in client:
    db = client[dbname]
else:
    db = client.create(dbname)

# %%
len(db.view('test/test', reduce=True))
# Out:
# 1

# %%
for item in db.view('test/test', group=True):
    print(item.key, item.value)
# Out:
# ar 4
# de 1
# en 125
# es 9
# und 8
# zh 1

# %%
for item in db.view('test/test'):
    print(item.key, item.value)
# Out:
# None 148

# %%
for item in db.view('Doc_test/new-view', group=True):
    print(item.key, item.value)
# Out:
# Aussie's 1
# Canberra, Australian Capital Territory 121
# Kowen, Canberra 1
# Paddys River, Canberra 25

# %%
db_adelaide = client["adelaide"]

# %%
for item in db_adelaide.view('Doc/view_place', group=True):
    print(item.key, item.value)
# Out:
# Adelaide Airport (ADL) 1
# Adelaide Convention Centre 1
# Adelaide Oval 3
# Adelaide, South Australia 2853
# Australia 2
# Brighton Beach 1
# Central Districts Football Club 1
# Foodworks 1
# Gawler, South Australia 7
# Glenelg Beach 1
# Glenelg, Adelaide 2
# Grange Beach 1
# Henley Beach 1
# Her Majesty's Theatre 1
# Hindmarsh Square 1
# Hope Valley, Adelaide 2
# James Coke Park 1
# Kurralta Park, Adelaide 1
# Meadows, South Australia 1
# Munno Para, Adelaide 1
# North Adelaide, Adelaide 1
# Nunyara Conference Centre 1
# Oyster Bar 1
# Paralowie, Adelaide 2
# Penfolds Magill Estate Cellar Door & Restaurant 1
# Port Adelaide Lighthouse 1
# Port Adelaide, Adelaide 2
# Salisbury Heights, Adelaide 1
# Scott Theatre 1
# South Australia, Australia 5
# Stepney, Adelaide 1
# Tanunda, South Australia 1
# Tea Tree Gully, Adelaide 2
# The University of Adelaide 1
# Thebarton Oval 1
# Tyrepower 1
# Victoria Square (Tarndanyangga) 1
# Vista, Adelaide 1
# Wayville, Adelaide 1
# West Beach 1
# ...

# %%
db_brisbane = client["brisbane"]
for item in db_brisbane.view('Doc/view_place', group=True):
    print(item.key, item.value)
# Out:
# Algester, Brisbane 5
# Amity Point, Queensland 2
# Aussie's 1
# Australia 34
# Banksia Beach, Bongaree - Woorim 1
# Bavarian Grill Haus 1
# Beerwah, Queensland 1
# Betty's Burgers 1
# Biometric Innovations 1
# Bongaree - Woorim, Queensland 8
# Boonah, Queensland 1
# Botanic Gardens Playground 2
# Bowen Hills, Brisbane 1
# Boyland, Queensland 1
# Brisbane Airport Domestic Terminal 1
# Brisbane City, Brisbane 3
# Brisbane, Queensland 4869
# Brooklyn Depot 1
# Cabbage Tree Creek 1
# Camp Mountain, Brisbane 3
# Canberra, Australian Capital Territory 104
# Capalaba, Brisbane 6
# Carindale, Brisbane 2
# City Botanic Gardens 3
# Clayfield, Brisbane 1
# Cleveland Point Lighthouse 1
# Coochiemudlo Island, Queensland 1
# Coolum Beach 1
# Doonan - Tinbeerwah, Queensland 1
# Eagleby Wetlands Reserve 1
# Esk, Queensland 16
# Eumundi, Queensland 2
# Fortitude Valley, Brisbane 2
# Frank Lind Oval 1
# Fully Stacked 1
# GJ Walter Park 1
# Global Change Institute 1
# Gold Coast, Queensland 748
# ...

# %%
db_Au = client["whole"]
N = 0
for item in db_Au.view('Doc/view_place', group=True):
    print(item.key, item.value)
    N = N + item.value
print(N)
# Out:
# 🐻 The Bear Den 🐼 2
# 1 Australia Avenue 1
# 12 Micron 1
# 2MQ 1
# 33 Mackenzie Street 1
# 3CR Community Radio 1
# 4 Parramatta Square 1
# 426 Bus 1
# 48h Pizza & Gnocchi Bar 1
# 77 King Street Building 1
# 9 degrees 3
# 96 Degrees 1
# AAMI Park 3
# Abandoned Hospital 2
# Abattoir Blues 2
# Abbey's Bookshop 2
# Abbotsford 1
# ABC Hobart 1
# ABC Melbourne 1
# ABC Newcastle 1
# Academy of Interactive Entertainment 1
# Acton 1
# Adaminaby 5
# Adelaide 5681
# Adelaide Airport (ADL) 1
# Adelaide Central Market 1
# Adelaide Convention Centre 1
# Adelaide Entertainment Centre 1
# Adelaide Oval 2
# Adelaide River 2
# Adelaide Studios 1
# Adelaide Town Hall 1
# Admiral Collingwood Lodge 1
# Afton Street Conservation Park 1
# Agnes Water 7
# Aireys Inlet - Fairhaven 5
# Airlie Beach - Cannonvale 22
# Ajisen Ramen 1
# Albany 110
# Albany Regional Hospital 1
# Albert Bridge 1
# Albert Park 2
# Albert Park Lake 1
# Alberton Oval 1
# Albion 1
# Albion Park 2
# Albury 359
# Aldinga 6
# Alexandra 2
# ...

# %%
db_Au = client["whole"]
N = 0
for item in db_Au.view('Doc/view_adelaide', group=True):
    print(item.key, item.value)
    N = N + item.value
print(N)
# Out:
# ar 27
# ca 6
# cs 2
# cy 2
# da 4
# de 2
# en 4595
# es 58
# et 11
# fa 65
# fi 1
# fr 15
# hi 8
# ht 6
# hu 1
# in 38
# is 1
# it 3
# ja 37
# nl 12
# no 5
# pl 3
# pt 13
# ro 2
# sl 1
# sv 4
# th 2
# tl 37
# tr 3
# und 638
# vi 2
# zh 77
# 5681

# %%
db_Au = client["whole"]
db_Sydney = client["sydney"]

S_LANG_DIC = {}
for item in db_Au.view('Doc/view_sydney', group=True):
    S_LANG_DIC[item.key] = item.value 
    
for item in db_Sydney.view('Doc/view_sydney_stream', group=True):
    S_LANG_DIC[item.key] = S_LANG_DIC[item.key] + item.value 
    
# with open("Syd_lang_comp.json",'r') as f:
#     grid_dict = json.load(f)
with open("Syd_lang_comp.json","w+",encoding="UTF-8") as fp:
    json.dump(S_LANG_DIC, fp)

# %%
db_Au = client["whole"]
db_Sydney = client["adelaide"]

S_LANG_DIC = {}
for item in db_Au.view('Doc/view_sydney', group=True):
    S_LANG_DIC[item.key] = item.value 
    
for item in db_Sydney.view('Doc/view_sydney_stream', group=True):
    S_LANG_DIC[item.key] = S_LANG_DIC[item.key] + item.value 
    
# with open("Syd_lang_comp.json",'r') as f:
#     grid_dict = json.load(f)
with open("Syd_lang_comp.json","w+",encoding="UTF-8") as fp:
    json.dump(S_LANG_DIC, fp)

# %% [markdown]
# ## language of city

# %%
def city_lang_comp(city:str):
    db_list = [f"{city}", f"{city}_tl7", "whole"]
    db_Au = client["whole"]
    db_current_city = client[f"{city}"]
    db_current_city_tl = client[f"{city}_tl7"]
    
    LANG_DIC = {}
    try:
        for item in db_Au.view('Doc/view_'+str(city)+'_lang', group=True):
            LANG_DIC[item.key] = item.value 

        for item in db_current_city.view('Doc/lang', group=True):
            LANG_DIC[item.key] = LANG_DIC[item.key] + item.value 

        for item in db_current_city_tl.view('Doc/lang', group=True):
            LANG_DIC[item.key] = LANG_DIC[item.key] + item.value 
    except:
        pass
    with open(str(city)+"_lang_comp.json","w+",encoding="UTF-8") as fp:
        json.dump(LANG_DIC, fp)

# %%
Cities = ["Sydney", "Melbourne", "Brisbane", "Perth", "Adelaide"]
cities = ["sydney", "melbourne", "brisbane", "perth", "adelaide"]

for city in cities:
    city_lang_comp(city)

# %%
print(S_LANG_DIC)
# Out:
# {'ar': 505, 'bg': 8, 'bn': 1, 'ca': 22, 'cs': 9, 'cy': 15, 'da': 16, 'de': 38, 'el': 42, 'en': 27395, 'es': 547, 'et': 146, 'eu': 7, 'fa': 155, 'fi': 12, 'fr': 92, 'hi': 100, 'ht': 53, 'hu': 7, 'in': 322, 'is': 18, 'it': 57, 'iw': 11, 'ja': 331, 'kn': 1, 'ko': 28, 'lt': 11, 'lv': 10, 'ne': 28, 'nl': 90, 'no': 9, 'pl': 26, 'pt': 338, 'ro': 7, 'ru': 200, 'sl': 3, 'sr': 3, 'sv': 19, 'te': 1, 'th': 209, 'tl': 387, 'tr': 347, 'uk': 3, 'und': 3494, 'ur': 48, 'vi': 2, 'zh': 261}

# %%
db_Au = client["whole"]
N = 0
for item in db_Au.view('test/test_point'):
#    print(item.key, item.value
    N = N + item.value
print(N)
# Out:
# 6033
